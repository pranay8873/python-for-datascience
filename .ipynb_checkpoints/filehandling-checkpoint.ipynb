# %%
f=open("text.txt",'r')
f.read()

# %%
f.readlines()

# %%
f.seek(0)

# %%
f.readline()

# %%
f.readline()

# %%
f.readlines()

# %%
f.close()

# %%
f=open("text.txt",'w')

# %%
f.write("using write function")

# %%
f.close()

# %%
with open("text.txt",'w') as f:
    f.write("\nsamuel\nbhavana\npranay\nvaishnavi")
