# %%
a="hello World"

# %%
a.lower()

# %%
a.upper()

# %%
a.strip()

# %%
b="    hello  world  "
b.strip()

# %%
b.strip("wor")

# %%
b.replace("hello","beautiful")

# %%
b.split()

# %%
c=b.split()

# %%
c

# %%
c=" ".join(c)
c

# %%
c.find("h")

# %%
c.count("h")

# %%
c.startswith("hello")

# %%
c.endswith("ld")

# %%
c.isdigit()

# %%
c.isalpha()

# %%
c.isalnum()

# %%
d="hello"
d.isalpha()

# %%
d="12345"
d.isdigit()

# %%
d="hel1234"
d.isalnum()
